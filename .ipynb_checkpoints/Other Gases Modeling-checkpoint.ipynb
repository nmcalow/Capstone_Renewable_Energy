# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from statsmodels.graphics.tsaplots import plot_pacf
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.graphics.tsaplots import plot_acf
pd.plotting.register_matplotlib_converters()
# %matplotlib inline

#from fbprophet import Prophet

# %%
df_recent = pd.read_csv('../data/energy_recent_clean.csv', index_col = 'date')
df_past = pd.read_csv('../data/energy_past_clean.csv', index_col = 'date')

df_recent.set_index(pd.to_datetime(df_recent.index), inplace = True)
df_past.set_index(pd.to_datetime(df_past.index), inplace = True)

# %% [markdown]
# ## Other Gases: [Source]()
#
# - There isn't much information about this source, but it is likely other sources of gas(like hydrogen or other plants) and considering it doesn't have a very large share of the energy budget, it won't matter

# %%
plt.figure(figsize = (20,12))
df_past['Other Gases'].plot()
df_recent['Other Gases'].plot()

#df_past['Total'].plot()
#df_recent['Total'].plot()

# %%
plt.figure(figsize = (20,12))
(df_past['Other Gases']/df_past['Total']).plot()
(df_recent['Other Gases']/df_recent['Total']).plot()
plt.title("Total Percentage of Generation By Other Gas Sources, 2001-2019", size = 20);

# %%
df_recent['Other Gases'].plot(figsize = (20,12))
df_recent['Other Gases'].rolling(12).mean().plot()

# %%
other = pd.DataFrame(data = df_recent.index)
other['y'] = list(df_recent['Other Gases'])
other.rename(columns = {'date': 'ds'}, inplace = True)
other['cap'] = 100
other.head()
# Out:
#           ds      y  cap
# 0 2001-01-01  718.0  100
# 1 2001-02-01  676.0  100
# 2 2001-03-01  769.0  100
# 3 2001-04-01  698.0  100
# 4 2001-05-01  785.0  100

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error
train, test = train_test_split(other, shuffle = False)
model_train = Prophet(growth = 'linear', seasonality_mode= 'multiplicative')
model_train.fit(train)
train_future = model_train.make_future_dataframe(periods = test.shape[0], freq = 'M')
train_pred = model_train.predict(train_future)
np.sqrt(mean_squared_error(test['y'], train_pred['yhat'][-55:]))
# Out:
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# 87.9536085192484

# %%
plt.figure(figsize = (20,12))
train_pred['yhat'][-55:].plot()
test['y'].plot()
plt.legend()

# %%
model_other = Prophet(growth = 'linear', seasonality_mode= 'multiplicative')
model_other.fit(other)
# Out:
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
other_future = model_other.make_future_dataframe(periods = 372, freq = 'M')
other_future['cap'] = 100
other_future.tail()
# Out:
#             ds  cap
# 587 2049-11-30  100
# 588 2049-12-31  100
# 589 2050-01-31  100
# 590 2050-02-28  100
# 591 2050-03-31  100

# %%
other_pred = model_other.predict(other_future)

# %%
other_pred[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail(15)
# Out:
#             ds         yhat  yhat_lower   yhat_upper
# 577 2049-01-31  1309.341018 -253.789526  2832.381787
# 578 2049-02-28  1353.159794 -286.368634  2963.026900
# 579 2049-03-31  1249.206100 -271.529344  2752.717870
# 580 2049-04-30  1436.261866 -343.544766  3123.853259
# 581 2049-05-31  1396.724176 -324.917989  3078.382820
# 582 2049-06-30  1507.751373 -344.145178  3320.135973
# 583 2049-07-31  1484.513086 -318.203083  3298.963991
# 584 2049-08-31  1417.399505 -356.912632  3145.799965
# 585 2049-09-30  1244.023289 -314.858119  2738.320734
# 586 2049-10-31  1252.579847 -339.382695  2804.149609
# 587 2049-11-30  1391.483581 -358.283171  3105.230429
# 588 2049-12-31  1435.737925 -367.382508  3196.753015
# 589 2050-01-31  1335.600356 -360.048006  2999.203803
# 590 2050-02-28  1344.985412 -375.614590  3058.406730
# 591 2050-03-31  1233.234004 -331.553076  2787.129778

# %%
fig1 = model_other.plot(other_pred)

# %%
fig2 = model_other.plot_components(other_pred)

# %% [markdown]
# ## Key Takeaways:
#
# -...It's pretty static around 1000. Doesn't seem to be going very far, and since I'm not even sure what this is measuring, that makes more sense than it skyrocketing

# %%
other_pred.to_csv("../data/Predictions_Other_Gases")
