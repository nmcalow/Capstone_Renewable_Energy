# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_recent = pd.read_csv('../data/energy_recent_clean.csv', index_col = 'date')
df_past = pd.read_csv('../data/energy_past_clean.csv', index_col = 'date')
pred_lower = pd.read_csv('../data/lower_predictions.csv', index_col = 'ds')
pred_mid = pd.read_csv('../data/midrange_predictions.csv', index_col = 'ds')
pred_upper = pd.read_csv('../data/upper_predictions.csv', index_col = 'ds')

df_recent.set_index(pd.to_datetime(df_recent.index), inplace = True)
df_past.set_index(pd.to_datetime(df_past.index), inplace = True)
pred_lower.set_index(pd.to_datetime(pred_lower.index), inplace = True)
pred_mid.set_index(pd.to_datetime(pred_mid.index), inplace = True)
pred_upper.set_index(pd.to_datetime(pred_upper.index), inplace = True)

# %%
pred_mid.head()
# Out:
#                      coal          ngas       other       nuclear  \
# ds
# 2001-01-01  174042.011175  44483.564855  823.251575  70399.396255
# 2001-02-01  150330.544240  39495.543292  761.170483  60755.894096
# 2001-03-01  147655.673411  43842.262644  880.888217  62020.311632
# 2001-04-01  134067.234696  42299.483978  848.908503  55837.384223
# 2001-05-01  147482.723118  46878.597359  875.183172  61866.275371
#
#                    hydro        wind          geo      solar          bio  \
# ds
# 2001-01-01  22418.459983  844.292784  1222.169092   5.570609  4337.558852
# 2001-02-01  20078.880804  793.023183  1086.037597   6.281624  3884.460604
# 2001-03-01  21839.778252  977.037369  1197.861512  10.177995  4184.048146
# 2001-04-01  21946.127587  988.357461  1127.617630  11.700127  3945.580034
# 2001-05-01  24506.493759  912.756438  1171.857187  13.932509  4088.191856
#
#                petroleum    renewables  nonrenewables          total  \
# ds
# 2001-01-01  14493.017665  28828.051320  304241.241525  333069.292845
# 2001-02-01  10306.142815  25848.683812  261649.294926  287497.978738
# 2001-03-01  10549.352475  28208.903274  264948.488379  293157.391653
# 2001-04-01   9665.162274  28019.382839  242718.173674  270737.556512
# 2001-05-01   9776.523949  30693.231749  266879.302967  297572.534716
#
#             renewable percent  nonrenewable percent
# ds
# 2001-01-01           0.086553              0.913447
# 2001-02-01           0.089909              0.910091
# 2001-03-01           0.096224              0.903776
# 2001-04-01           0.103493              0.896507
# 2001-05-01           0.103145              0.896855

# %%
errors = {
    'Coal': 8490.156403017965,
    'Natural Gas':11943.975587108984,
    'Nuclear':3220.931184127836,
    'Petroleum': 1071.313800411348,
    'Other Gases':87.9536085192484,
    'Wind':5691.517791985315,
    'Solar':5096.576778447611,
    'Hydroelectric': 2757.503247227439,
    'Geothermal': 57.18855074779286,
    'Biomass':457.99136833204983
}

# %%
rmse = pd.Series()
for key in errors.keys():
    rmse[key] = errors[key]
rmse.sort_values(ascending = False, inplace = True)

# %%
plt.figure(figsize = (20,12))
sns.barplot(x = rmse.index, y = rmse.values)
plt.title("Root Mean Squared Error of Each Sector", size = 24);

# %%
plt.figure(figsize = (20,12))
pred_mid['total'].plot()
pred_mid['renewables'].plot()
pred_mid['nonrenewables'].plot()
plt.title("Renewable and Nonrenewable Totals Versus Overall Total(2001-2049)", size = 28);

# %%
plt.figure(figsize = (20,12))
pred_mid['renewable percent'].plot(color = 'green')
pred_mid['nonrenewable percent'].plot(color = 'orange')
plt.title("Midrange Renewable Versus Nonrenewable Percentage(2001-2049)", size = 28);

# %%
plt.figure(figsize = (24,12))

df_past['Renewable Percentage'].plot()
pred_mid['renewable percent'].rolling(12).mean().plot(color = 'black', label = "Mid")
pred_lower['renewable percent'].rolling(12).mean().plot(color = 'blue', label = 'Low')
pred_upper['renewable percent'].rolling(12).mean().plot(color = 'red', label = 'High')

df_past['Nonrenewable Percentage'].plot()
pred_mid['nonrenewable percent'].rolling(12).mean().plot(color = 'black', label = "Mid")
pred_lower['nonrenewable percent'].rolling(12).mean().plot(color = 'blue', label = 'Low')
pred_upper['nonrenewable percent'].rolling(12).mean().plot(color = 'red', label = 'High')
plt.title('Renewable Versus Nonrenewable Percentage Over Time(1949-2049)', size = 28)
plt.axhline(0.5, color = 'red');

# %%
plt.figure(figsize = (20,20))
pred_lower['renewables'].rolling(12).mean().plot(color = 'blue', label = 'Lower')
pred_mid['renewables'].rolling(12).mean().plot(color = 'black', label = "Midrange")
pred_upper['renewables'].rolling(12).mean().plot(color = 'red', label = "Upper")

pred_lower['nonrenewables'].rolling(12).mean().plot(color = 'blue', label = 'Lower')
pred_mid['nonrenewables'].rolling(12).mean().plot(color = 'black', label = "Midrange")
pred_upper['nonrenewables'].rolling(12).mean().plot(color = 'red', label = 'Upper')
plt.legend()
plt.title("Renewable Versus Nonrenewable Rolling Totals", size = 28);

# %%
features = ['renewables', 'nonrenewables', 'renewable percent', 'nonrenewable percent', 'total']

# %%
pred_mid[pred_mid['renewables'] > pred_mid['nonrenewables']][features].head()
# Out:
#                renewables  nonrenewables  renewable percent  \
# ds
# 2035-03-31  204371.137316  202435.358511           0.502379
# 2035-04-30  229651.600915  228966.746027           0.500747
# 2036-03-31  213336.939455  208593.772583           0.505621
# 2037-03-31  219575.563483  209023.973118           0.512309
# 2037-04-30  235185.521791  234047.481585           0.501213
#
#             nonrenewable percent          total
# ds
# 2035-03-31              0.497621  406806.495827
# 2035-04-30              0.499253  458618.346942
# 2036-03-31              0.494379  421930.712039
# 2037-03-31              0.487691  428599.536600
# 2037-04-30              0.498787  469233.003376

# %%
pred_lower[pred_lower['renewables'] > pred_lower['nonrenewables']][features].head()
# Out:
#                renewables  nonrenewables  renewable percent  \
# ds
# 2038-03-31  192872.611808  190003.919343           0.503746
# 2039-03-31  195934.267901  189372.878625           0.508514
# 2039-04-30  220347.177171  216865.208384           0.503982
# 2040-03-31  201866.777639  194537.205302           0.509245
# 2041-03-31  204984.506231  193948.922528           0.513831
#
#             nonrenewable percent          total
# ds
# 2038-03-31              0.496254  382876.531151
# 2039-03-31              0.491486  385307.146526
# 2039-04-30              0.496018  437212.385555
# 2040-03-31              0.490755  396403.982941
# 2041-03-31              0.486169  398933.428760

# %%
pred_upper[pred_upper['renewables'] > pred_upper['nonrenewables']][features].head()
# Out:
#                renewables  nonrenewables  renewable percent  \
# ds
# 2043-03-31  283415.074042  282133.370804           0.501133
#
#             nonrenewable percent          total
# ds
# 2043-03-31              0.498867  565548.444846

# %% [markdown]
# ## Final Assessment: Electricity generation in the United States will be at least 50% renewable for the first time between 2035 and 2043 with an 80% confidence
